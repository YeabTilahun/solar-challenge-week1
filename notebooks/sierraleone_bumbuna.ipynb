# %%
import sys
import os
sys.path.append(os.path.abspath('../scripts'))

from data_utils import SolarDataProcessor # type: ignore

processor = SolarDataProcessor("data/sierraleone-bumbuna.csv")

processor.summarize()

columns = ['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust']
processor.detect_outliers(columns)
processor.impute_medians(columns)

processor.save_cleaned("data/cleaned/togo_clean.csv")

# Plots
processor.plot_time_series()
processor.plot_cleaning_effect()
processor.plot_correlation_heatmap()
processor.plot_scatter()
processor.plot_wind_rose()
processor.plot_histograms()
processor.plot_bubble_chart()
# Out:
# Summary Statistics
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      201.957515     116.376337     113.720571     206.643095
# std       298.495150     218.652659     158.946032     300.896893
# min       -19.500000      -7.800000     -17.900000       0.000000
# 25%        -2.800000      -0.300000      -3.800000       0.000000
# 50%         0.300000      -0.100000      -0.100000       3.600000
# 75%       362.400000     107.000000     224.700000     359.500000
# max      1499.000000     946.000000     892.000000    1507.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      198.114691      26.319394      79.448857       1.146113
# std       288.889073       4.398605      20.520775       1.239248
# min         0.000000      12.300000       9.900000       0.000000
# ...
